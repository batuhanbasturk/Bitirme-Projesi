# %%
import pandas as pd
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from xgboost import XGBRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from xgboost import plot_importance

# %%
df = pd.read_csv('../../data/preprocessed/main-data.csv') 

# convert day to numerical

le = LabelEncoder()
df['day'] = le.fit_transform(df['day'])
df.drop(['category_names','packet_date'], axis=1, inplace=True)

df['is_vip'] = df['is_vip'].astype(int)

# Define features and target variable
X = df[df.columns.difference(['collection_duration'])]
y = df['collection_duration']

# %%
def XGBOOST_Evaluate(X_train, X_test, y_train, y_test):
    # Define hyperparameter grid for XGBoost
    parameters = {
        'objective': ['reg:squarederror'],
        'booster': ['gbtree'],
        'learning_rate': [0.1, 0.2, 0.3],
        'max_depth': [7, 10, 15, 20, 25, 30],
        'min_child_weight': [10, 15, 20, 25],
        'colsample_bytree': [0.8, 0.9, 1],
        'n_estimators': [100, 200, 300, 400, 500, 600],
        "reg_alpha": [0.5, 0.2, 1],
        "reg_lambda": [2, 3, 5],
        "gamma": [1, 2, 3]
    }

    # Initialize XGBoost model
    xgb_model = XGBRegressor(random_state=42)

    # Initialize RandomizedSearchCV
    grid_xgb = RandomizedSearchCV(xgb_model, parameters, cv=10, n_iter=10, scoring='neg_mean_absolute_error', verbose=0, n_jobs= -1)

    # Fit RandomizedSearchCV
    grid_xgb.fit(X_train, y_train)

    # Extract best estimator
    best_xgb_model = grid_xgb.best_estimator_

    # Train final XGBoost model with best hyperparameters
    best_xgb_model.fit(X_train, y_train, eval_metric=["rmse"], eval_set=[(X_train, y_train), (X_test, y_test)])

    # Make predictions on the test set
    y_pred = best_xgb_model.predict(X_test)

    # Evaluate predictions
    rmse = root_mean_squared_error(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)
    rsquared = r2_score(y_test, y_pred)
    mse = np.mean((y_test - y_pred) ** 2)
    mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100

    print("R-squared: %.4f" % rsquared)
    print("RMSE: %.4f" % rmse)
    print("MAE : %.4f" % mae)
    print("MSE : %.4f" % mse)
    print("MAPE: %.4f" % mape)

    p_accuracy = [(1 - np.abs(pred - actual) / actual) * 100 for pred, actual in zip(y_pred, y_test)]

    # Print P_accuracy
    print("P_accuracy: Mean: %.2f%%, Min: %.2f%%, Max: %.2f%%" % (np.mean(p_accuracy), np.min(p_accuracy), np.max(p_accuracy)))
    
    # print best hyperparameters
    results = best_xgb_model.evals_result()
    
    print("Best hyperparameters:", grid_xgb.best_params_)
    print('--------------------------------------------------')


    return results, y_test, y_pred, rmse, mae, rsquared, p_accuracy

# %%
# Defining the features to be used for training
feature_combinations = [
    df.columns.difference(['collection_duration', 'day', 'year', 'month', 'hour']),
    df.columns.difference(['collection_duration', 'day', 'year', 'month', 'hour', 'unique_category_count']),
    df.columns.difference(['collection_duration', 'day', 'year', 'month', 'hour', 'unique_category_count', 'average_collection_time']),
    df.columns.difference(['collection_duration', 'day', 'year', 'month', 'hour', 'average_collection_time']),
    df.columns.difference(['collection_duration', 'unique_category_count', 'average_collection_time']),
    df.columns.difference(['collection_duration', 'unique_category_count']),
    df.columns.difference(['collection_duration', 'average_collection_time']),
    df.columns.difference(['collection_duration']),
]

# %%
for features in feature_combinations:
    X = df[features]
    y = df['collection_duration']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
    print(f"Training and evaluating model for features: {features}")
    results, y_test, y_pred, rmse, mae, rsquared, p_accuracy = XGBOOST_Evaluate(X_train, X_test, y_train, y_test)
    print("R-squared: %.4f" % rsquared)
    print("RMSE: %.4f" % rmse)
    print("MAE : %.4f" % mae)
    print("P_accuracy: Mean: %.2f%%, Min: %.2f%%, Max: %.2f%%" % (np.mean(p_accuracy), np.min(p_accuracy), np.max(p_accuracy)))
# Out:
# Training and evaluating model for features: Index(['Baby', 'Bakery', 'Cleaning&Household_Supplies', 'Clothing&Accessory',
#        'ConvenienceFood&Appetizers', 'Drinks', 'Frozen_food',
#        'Fruits&Vegetables', 'Health', 'Healthy_Living', 'Hobby&Game',
#        'Home_Care', 'Icecream', 'Meat&Fish', 'Milk&Breakfast', 'Others',
#        'Personal_Care&Cosmetics', 'Pet', 'Snacks', 'Special_Days',
#        'Staple_Food', 'Technology', 'average_collection_time', 'is_holiday',
#        'is_vip', 'item_count', 'unique_category_count'],
#       dtype='object')
# [0]	validation_0-rmse:2.51908	validation_1-rmse:2.52167
# [1]	validation_0-rmse:2.43917	validation_1-rmse:2.44185
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/sklearn.py:889: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# [2]	validation_0-rmse:2.37245	validation_1-rmse:2.37525
# [3]	validation_0-rmse:2.31692	validation_1-rmse:2.31989
# [4]	validation_0-rmse:2.27092	validation_1-rmse:2.27405
# [5]	validation_0-rmse:2.23293	validation_1-rmse:2.23625
# [6]	validation_0-rmse:2.20164	validation_1-rmse:2.20518
# [7]	validation_0-rmse:2.17591	validation_1-rmse:2.17964
# [8]	validation_0-rmse:2.15481	validation_1-rmse:2.15874
# [9]	validation_0-rmse:2.13750	validation_1-rmse:2.14163
# [10]	validation_0-rmse:2.12338	validation_1-rmse:2.12767
# [11]	validation_0-rmse:2.11452	validation_1-rmse:2.11915
# [12]	validation_0-rmse:2.10601	validation_1-rmse:2.11086
# [13]	validation_0-rmse:2.09996	validation_1-rmse:2.10512
# [14]	validation_0-rmse:2.09258	validation_1-rmse:2.09793
# [15]	validation_0-rmse:2.08659	validation_1-rmse:2.09211
# [16]	validation_0-rmse:2.08164	validation_1-rmse:2.08736
# [17]	validation_0-rmse:2.07762	validation_1-rmse:2.08353
# [18]	validation_0-rmse:2.07432	validation_1-rmse:2.08037
# [19]	validation_0-rmse:2.07161	validation_1-rmse:2.07786
# [20]	validation_0-rmse:2.06937	validation_1-rmse:2.07578
# [21]	validation_0-rmse:2.06751	validation_1-rmse:2.07411
# [22]	validation_0-rmse:2.06599	validation_1-rmse:2.07277
# [23]	validation_0-rmse:2.06472	validation_1-rmse:2.07160
# [24]	validation_0-rmse:2.06367	validation_1-rmse:2.07073
# [25]	validation_0-rmse:2.06278	validation_1-rmse:2.07001
# [26]	validation_0-rmse:2.06203	validation_1-rmse:2.06944
# [27]	validation_0-rmse:2.06139	validation_1-rmse:2.06893
# [28]	validation_0-rmse:2.06090	validation_1-rmse:2.06854
# [29]	validation_0-rmse:2.06040	validation_1-rmse:2.06823
# [30]	validation_0-rmse:2.06003	validation_1-rmse:2.06799
# [31]	validation_0-rmse:2.05968	validation_1-rmse:2.06775
# [32]	validation_0-rmse:2.05937	validation_1-rmse:2.06759
# [33]	validation_0-rmse:2.05909	validation_1-rmse:2.06742
# [34]	validation_0-rmse:2.05886	validation_1-rmse:2.06735
# [35]	validation_0-rmse:2.05864	validation_1-rmse:2.06728
# [36]	validation_0-rmse:2.05842	validation_1-rmse:2.06719
# [37]	validation_0-rmse:2.05821	validation_1-rmse:2.06709
# [38]	validation_0-rmse:2.05802	validation_1-rmse:2.06704
# [39]	validation_0-rmse:2.05785	validation_1-rmse:2.06701
# [40]	validation_0-rmse:2.05771	validation_1-rmse:2.06697
# [41]	validation_0-rmse:2.05756	validation_1-rmse:2.06692
# [42]	validation_0-rmse:2.05741	validation_1-rmse:2.06688
# [43]	validation_0-rmse:2.05726	validation_1-rmse:2.06688
# [44]	validation_0-rmse:2.05709	validation_1-rmse:2.06686
# [45]	validation_0-rmse:2.05698	validation_1-rmse:2.06682
# [46]	validation_0-rmse:2.05686	validation_1-rmse:2.06680
# [47]	validation_0-rmse:2.05674	validation_1-rmse:2.06678
# [48]	validation_0-rmse:2.05660	validation_1-rmse:2.06677
# [49]	validation_0-rmse:2.05649	validation_1-rmse:2.06675
# [50]	validation_0-rmse:2.05634	validation_1-rmse:2.06674
# [51]	validation_0-rmse:2.05622	validation_1-rmse:2.06674
# [52]	validation_0-rmse:2.05610	validation_1-rmse:2.06675
# [53]	validation_0-rmse:2.05601	validation_1-rmse:2.06672
# [54]	validation_0-rmse:2.05585	validation_1-rmse:2.06671
# [55]	validation_0-rmse:2.05575	validation_1-rmse:2.06672
# [56]	validation_0-rmse:2.05566	validation_1-rmse:2.06674
# [57]	validation_0-rmse:2.05559	validation_1-rmse:2.06676
# [58]	validation_0-rmse:2.05545	validation_1-rmse:2.06676
# [59]	validation_0-rmse:2.05536	validation_1-rmse:2.06675
# [60]	validation_0-rmse:2.05527	validation_1-rmse:2.06677
# [61]	validation_0-rmse:2.05522	validation_1-rmse:2.06677
# [62]	validation_0-rmse:2.05514	validation_1-rmse:2.06679
# [63]	validation_0-rmse:2.05509	validation_1-rmse:2.06680
# [64]	validation_0-rmse:2.05502	validation_1-rmse:2.06682
# [65]	validation_0-rmse:2.05490	validation_1-rmse:2.06683
# [66]	validation_0-rmse:2.05486	validation_1-rmse:2.06684
# [67]	validation_0-rmse:2.05481	validation_1-rmse:2.06686
# [68]	validation_0-rmse:2.05472	validation_1-rmse:2.06687
# [69]	validation_0-rmse:2.05465	validation_1-rmse:2.06686
# [70]	validation_0-rmse:2.05459	validation_1-rmse:2.06685
# [71]	validation_0-rmse:2.05457	validation_1-rmse:2.06687
# [72]	validation_0-rmse:2.05449	validation_1-rmse:2.06688
# [73]	validation_0-rmse:2.05446	validation_1-rmse:2.06689
# [74]	validation_0-rmse:2.05439	validation_1-rmse:2.06691
# [75]	validation_0-rmse:2.05435	validation_1-rmse:2.06691
# [76]	validation_0-rmse:2.05434	validation_1-rmse:2.06692
# [77]	validation_0-rmse:2.05426	validation_1-rmse:2.06690
# [78]	validation_0-rmse:2.05421	validation_1-rmse:2.06692
# [79]	validation_0-rmse:2.05415	validation_1-rmse:2.06692
# [80]	validation_0-rmse:2.05410	validation_1-rmse:2.06691
# [81]	validation_0-rmse:2.05408	validation_1-rmse:2.06691
# [82]	validation_0-rmse:2.05400	validation_1-rmse:2.06693
# [83]	validation_0-rmse:2.05396	validation_1-rmse:2.06694
# [84]	validation_0-rmse:2.05388	validation_1-rmse:2.06695
# [85]	validation_0-rmse:2.05384	validation_1-rmse:2.06697
# [86]	validation_0-rmse:2.05379	validation_1-rmse:2.06696
# [87]	validation_0-rmse:2.05375	validation_1-rmse:2.06697
# [88]	validation_0-rmse:2.05370	validation_1-rmse:2.06697
# [89]	validation_0-rmse:2.05368	validation_1-rmse:2.06698
# [90]	validation_0-rmse:2.05365	validation_1-rmse:2.06698
# [91]	validation_0-rmse:2.05360	validation_1-rmse:2.06702
# [92]	validation_0-rmse:2.05358	validation_1-rmse:2.06701
# [93]	validation_0-rmse:2.05353	validation_1-rmse:2.06702
# [94]	validation_0-rmse:2.05350	validation_1-rmse:2.06704
# [95]	validation_0-rmse:2.05346	validation_1-rmse:2.06703
# [96]	validation_0-rmse:2.05340	validation_1-rmse:2.06705
# [97]	validation_0-rmse:2.05335	validation_1-rmse:2.06706
# [98]	validation_0-rmse:2.05331	validation_1-rmse:2.06706
# [99]	validation_0-rmse:2.05316	validation_1-rmse:2.06707
# [100]	validation_0-rmse:2.05311	validation_1-rmse:2.06709
# [101]	validation_0-rmse:2.05304	validation_1-rmse:2.06708
# [102]	validation_0-rmse:2.05302	validation_1-rmse:2.06709
# [103]	validation_0-rmse:2.05301	validation_1-rmse:2.06709
# [104]	validation_0-rmse:2.05297	validation_1-rmse:2.06709
# [105]	validation_0-rmse:2.05289	validation_1-rmse:2.06711
# [106]	validation_0-rmse:2.05284	validation_1-rmse:2.06711
# [107]	validation_0-rmse:2.05281	validation_1-rmse:2.06711
# [108]	validation_0-rmse:2.05275	validation_1-rmse:2.06712
# [109]	validation_0-rmse:2.05268	validation_1-rmse:2.06713
# [110]	validation_0-rmse:2.05267	validation_1-rmse:2.06713
# [111]	validation_0-rmse:2.05260	validation_1-rmse:2.06714
# [112]	validation_0-rmse:2.05253	validation_1-rmse:2.06714
# [113]	validation_0-rmse:2.05249	validation_1-rmse:2.06714
# [114]	validation_0-rmse:2.05242	validation_1-rmse:2.06715
# [115]	validation_0-rmse:2.05239	validation_1-rmse:2.06715
# [116]	validation_0-rmse:2.05237	validation_1-rmse:2.06716
# [117]	validation_0-rmse:2.05225	validation_1-rmse:2.06721
# [118]	validation_0-rmse:2.05222	validation_1-rmse:2.06723
# [119]	validation_0-rmse:2.05218	validation_1-rmse:2.06726
# [120]	validation_0-rmse:2.05217	validation_1-rmse:2.06727
# [121]	validation_0-rmse:2.05206	validation_1-rmse:2.06728
# [122]	validation_0-rmse:2.05199	validation_1-rmse:2.06730
# [123]	validation_0-rmse:2.05192	validation_1-rmse:2.06731
# [124]	validation_0-rmse:2.05187	validation_1-rmse:2.06732
# [125]	validation_0-rmse:2.05181	validation_1-rmse:2.06731
# [126]	validation_0-rmse:2.05178	validation_1-rmse:2.06732
# [127]	validation_0-rmse:2.05176	validation_1-rmse:2.06735
# [128]	validation_0-rmse:2.05173	validation_1-rmse:2.06735
# [129]	validation_0-rmse:2.05172	validation_1-rmse:2.06736
# [130]	validation_0-rmse:2.05159	validation_1-rmse:2.06740
# [131]	validation_0-rmse:2.05144	validation_1-rmse:2.06740
# [132]	validation_0-rmse:2.05144	validation_1-rmse:2.06741
# [133]	validation_0-rmse:2.05141	validation_1-rmse:2.06742
# [134]	validation_0-rmse:2.05135	validation_1-rmse:2.06741
# [135]	validation_0-rmse:2.05130	validation_1-rmse:2.06743
# [136]	validation_0-rmse:2.05127	validation_1-rmse:2.06743
# [137]	validation_0-rmse:2.05119	validation_1-rmse:2.06746
# [138]	validation_0-rmse:2.05113	validation_1-rmse:2.06744
# [139]	validation_0-rmse:2.05110	validation_1-rmse:2.06746
# [140]	validation_0-rmse:2.05108	validation_1-rmse:2.06749
# [141]	validation_0-rmse:2.05102	validation_1-rmse:2.06749
# [142]	validation_0-rmse:2.05098	validation_1-rmse:2.06749
# [143]	validation_0-rmse:2.05096	validation_1-rmse:2.06750
# [144]	validation_0-rmse:2.05092	validation_1-rmse:2.06752
# [145]	validation_0-rmse:2.05080	validation_1-rmse:2.06755
# [146]	validation_0-rmse:2.05074	validation_1-rmse:2.06756
# [147]	validation_0-rmse:2.05067	validation_1-rmse:2.06757
# [148]	validation_0-rmse:2.05064	validation_1-rmse:2.06756
# [149]	validation_0-rmse:2.05051	validation_1-rmse:2.06759
# [150]	validation_0-rmse:2.05046	validation_1-rmse:2.06760
# [151]	validation_0-rmse:2.05045	validation_1-rmse:2.06760
# [152]	validation_0-rmse:2.05038	validation_1-rmse:2.06762
# [153]	validation_0-rmse:2.05027	validation_1-rmse:2.06763
# [154]	validation_0-rmse:2.05026	validation_1-rmse:2.06764
# [155]	validation_0-rmse:2.05016	validation_1-rmse:2.06763
# [156]	validation_0-rmse:2.05014	validation_1-rmse:2.06765
# [157]	validation_0-rmse:2.05012	validation_1-rmse:2.06765
# [158]	validation_0-rmse:2.05008	validation_1-rmse:2.06767
# [159]	validation_0-rmse:2.05003	validation_1-rmse:2.06766
# [160]	validation_0-rmse:2.04997	validation_1-rmse:2.06768
# [161]	validation_0-rmse:2.04986	validation_1-rmse:2.06768
# [162]	validation_0-rmse:2.04979	validation_1-rmse:2.06770
# [163]	validation_0-rmse:2.04971	validation_1-rmse:2.06770
# [164]	validation_0-rmse:2.04965	validation_1-rmse:2.06769
# [165]	validation_0-rmse:2.04961	validation_1-rmse:2.06770
# [166]	validation_0-rmse:2.04953	validation_1-rmse:2.06771
# [167]	validation_0-rmse:2.04945	validation_1-rmse:2.06772
# [168]	validation_0-rmse:2.04941	validation_1-rmse:2.06772
# [169]	validation_0-rmse:2.04936	validation_1-rmse:2.06773
# [170]	validation_0-rmse:2.04928	validation_1-rmse:2.06774
# [171]	validation_0-rmse:2.04926	validation_1-rmse:2.06777
# [172]	validation_0-rmse:2.04920	validation_1-rmse:2.06780
# [173]	validation_0-rmse:2.04915	validation_1-rmse:2.06781
# [174]	validation_0-rmse:2.04906	validation_1-rmse:2.06781
# [175]	validation_0-rmse:2.04902	validation_1-rmse:2.06783
# [176]	validation_0-rmse:2.04896	validation_1-rmse:2.06785
# [177]	validation_0-rmse:2.04896	validation_1-rmse:2.06785
# [178]	validation_0-rmse:2.04896	validation_1-rmse:2.06785
# [179]	validation_0-rmse:2.04887	validation_1-rmse:2.06786
# [180]	validation_0-rmse:2.04880	validation_1-rmse:2.06788
# [181]	validation_0-rmse:2.04879	validation_1-rmse:2.06788
# [182]	validation_0-rmse:2.04875	validation_1-rmse:2.06790
# [183]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [184]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [185]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [186]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [187]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [188]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [189]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [190]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [191]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [192]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [193]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [194]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [195]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [196]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [197]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [198]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [199]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [200]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [201]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [202]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [203]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [204]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [205]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [206]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [207]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [208]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [209]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [210]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [211]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [212]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [213]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [214]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [215]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [216]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [217]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [218]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [219]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [220]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [221]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [222]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [223]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [224]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [225]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [226]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [227]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [228]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [229]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [230]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [231]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [232]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [233]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [234]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [235]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [236]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [237]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [238]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [239]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [240]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [241]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [242]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [243]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [244]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [245]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [246]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [247]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [248]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [249]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [250]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [251]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [252]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [253]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [254]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [255]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [256]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [257]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [258]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [259]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [260]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [261]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [262]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [263]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [264]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [265]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [266]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [267]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [268]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [269]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [270]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [271]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [272]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [273]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [274]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [275]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [276]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [277]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [278]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [279]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [280]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [281]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [282]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [283]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [284]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [285]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [286]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [287]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [288]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [289]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [290]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [291]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [292]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [293]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [294]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [295]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [296]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [297]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [298]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# [299]	validation_0-rmse:2.04872	validation_1-rmse:2.06791
# R-squared: 0.3755
# RMSE: 2.0679
# MAE : 1.6264
# MSE : 4.2762
# MAPE: 31.4852
# P_accuracy: Mean: 68.51%, Min: -107.16%, Max: 100.00%
# Best hyperparameters: {'reg_lambda': 2, 'reg_alpha': 0.2, 'objective': 'reg:squarederror', 'n_estimators': 300, 'min_child_weight': 15, 'max_depth': 7, 'learning_rate': 0.1, 'gamma': 3, 'colsample_bytree': 0.8, 'booster': 'gbtree'}
# --------------------------------------------------
# R-squared: 0.3755
# RMSE: 2.0679
# MAE : 1.6264
# P_accuracy: Mean: 68.51%, Min: -107.16%, Max: 100.00%
# Training and evaluating model for features: Index(['Baby', 'Bakery', 'Cleaning&Household_Supplies', 'Clothing&Accessory',
#        'ConvenienceFood&Appetizers', 'Drinks', 'Frozen_food',
#        'Fruits&Vegetables', 'Health', 'Healthy_Living', 'Hobby&Game',
#        'Home_Care', 'Icecream', 'Meat&Fish', 'Milk&Breakfast', 'Others',
#        'Personal_Care&Cosmetics', 'Pet', 'Snacks', 'Special_Days',
#        'Staple_Food', 'Technology', 'average_collection_time', 'is_holiday',
#        'is_vip', 'item_count'],
#       dtype='object')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 6
#       4 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
#       5 print(f"Training and evaluating model for features: {features}")
# ----> 6 results, y_test, y_pred, rmse, mae, rsquared, p_accuracy = XGBOOST_Evaluate(X_train, X_test, y_train, y_test)
#       7 print("R-squared: %.4f" % rsquared)
#       8 print("RMSE: %.4f" % rmse)
#
# Cell In[8], line 23, in XGBOOST_Evaluate(X_train, X_test, y_train, y_test)
#      20 grid_xgb = RandomizedSearchCV(xgb_model, parameters, cv=10, n_iter=10, scoring='neg_mean_absolute_error', verbose=0, n_jobs= -1)
#      22 # Fit RandomizedSearchCV
# ---> 23 grid_xgb.fit(X_train, y_train)
#      25 # Extract best estimator
#      26 best_xgb_model = grid_xgb.best_estimator_
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/model_selection/_search.py:970, in BaseSearchCV.fit(self, X, y, **params)
#     964     results = self._format_results(
#     965         all_candidate_params, n_splits, all_out, all_more_results
#     966     )
#     968     return results
# --> 970 self._run_search(evaluate_candidates)
#     972 # multimetric is determined here because in the case of a callable
#     973 # self.scoring the return type is only known after calling
#     974 first_test_score = all_out[0]["test_scores"]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1914, in RandomizedSearchCV._run_search(self, evaluate_candidates)
#    1912 def _run_search(self, evaluate_candidates):
#    1913     """Search n_iter candidates from param_distributions"""
# -> 1914     evaluate_candidates(
#    1915         ParameterSampler(
#    1916             self.param_distributions, self.n_iter, random_state=self.random_state
#    1917         )
#    1918     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/model_selection/_search.py:916, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     908 if self.verbose > 0:
#     909     print(
#     910         "Fitting {0} folds for each of {1} candidates,"
#     911         " totalling {2} fits".format(
#     912             n_splits, n_candidates, n_candidates * n_splits
#     913         )
#     914     )
# --> 916 out = parallel(
#     917     delayed(_fit_and_score)(
#     918         clone(base_estimator),
#     919         X,
#     920         y,
#     921         train=train,
#     922         test=test,
#     923         parameters=parameters,
#     924         split_progress=(split_idx, n_splits),
#     925         candidate_progress=(cand_idx, n_candidates),
#     926         **fit_and_score_kwargs,
#     927     )
#     928     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     929         enumerate(candidate_params),
#     930         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     931     )
#     932 )
#     934 if len(out) < 1:
#     935     raise ValueError(
#     936         "No fits were performed. "
#     937         "Was the CV iterator empty? "
#     938         "Were there no candidates?"
#     939     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/parallel.py:67, in Parallel.__call__(self, iterable)
#      62 config = get_config()
#      63 iterable_with_config = (
#      64     (_with_config(delayed_func, config), args, kwargs)
#      65     for delayed_func, args, kwargs in iterable
#      66 )
# ---> 67 return super().__call__(iterable_with_config)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/joblib/parallel.py:1952, in Parallel.__call__(self, iterable)
#    1946 # The first item from the output is blank, but it makes the interpreter
#    1947 # progress until it enters the Try/Except block of the generator and
#    1948 # reach the first `yield` statement. This starts the aynchronous
#    1949 # dispatch of the tasks to the workers.
#    1950 next(output)
# -> 1952 return output if self.return_generator else list(output)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/joblib/parallel.py:1595, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1592     yield
#    1594     with self._backend.retrieval_context():
# -> 1595         yield from self._retrieve()
#    1597 except GeneratorExit:
#    1598     # The generator has been garbage collected before being fully
#    1599     # consumed. This aborts the remaining tasks if possible and warn
#    1600     # the user if necessary.
#    1601     self._exception = True
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/joblib/parallel.py:1707, in Parallel._retrieve(self)
#    1702 # If the next job is not ready for retrieval yet, we just wait for
#    1703 # async callbacks to progress.
#    1704 if ((len(self._jobs) == 0) or
#    1705     (self._jobs[0].get_status(
#    1706         timeout=self.timeout) == TASK_PENDING)):
# -> 1707     time.sleep(0.01)
#    1708     continue
#    1710 # We need to be careful: the job list can be filling up as
#    1711 # we empty it and Python list are not thread-safe by
#    1712 # default hence the use of the lock
#
# KeyboardInterrupt:
